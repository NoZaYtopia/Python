# %%
def f(x):
    return x*x*x*x-x-1
a=-10
b=1
e=0.0001
id=0
while abs(a-b)>e:
    d=(a+b)/2
    if f(a)*f(d)<0:
        b=d
    else:
        if f(b)*f(d)<0:
            a=d
    id=id+1
print (a)
print (b)
print (f(a))
print (f(b))
print (id)
# Out:
# -0.7245407104492188
# -0.724456787109375
# 0.00012291526367835814
# -8.866832040255179e-05
# 17

# %%
def f(x):
    return x*x*x*x-x-1
a=-10
b=1
e=0.0001

#while abs(a-b)>e:
for i in range(100):
    d=(a+b)/2
    if f(a)*f(d)<0:
        b=d
    else:
        if f(b)*f(d)<0:
            a=d
    print (f(a)," ",f(b))
# Out:
# 413.5625   -1
# 10.12890625   -1
# 10.12890625   -0.605224609375
# 1.3369293212890625   -0.605224609375
# 1.3369293212890625   -0.014372825622558594
# 0.5198116898536682   -0.014372825622558594
# 0.22397220507264137   -0.014372825622558594
# 0.09836872317828238   -0.014372825622558594
# 0.04048021302151028   -0.014372825622558594
# 0.012685230861279706   -0.014372825622558594
# 0.012685230861279706   -0.0009345591797114139
# 0.005852476932435735   -0.0009345591797114139
# 0.002453265255361936   -0.0009345591797114139
# 0.0007579322665691723   -0.0009345591797114139
# 0.0007579322665691723   -8.866832040255179e-05
# 0.00033454321601444903   -8.866832040255179e-05
# 0.00012291526367835814   -8.866832040255179e-05
# 1.7117926248477744e-05   -8.866832040255179e-05
# 1.7117926248477744e-05   -3.5776583344193646e-05
# 1.7117926248477744e-05   -9.329675124680747e-06
# 3.8940389164299205e-06   -9.329675124680747e-06
# 3.8940389164299205e-06   -2.71783976535378e-06
# ...

# %%
def f(x):
    return x*x*x*x-x-1
a=-10
b=1
e=0.0001
ih=0
k=(f(b)-f(a))/abs(a-b)
q=f(b)-k*b
d=-q/k
if f(a)*f(d)<0:
    b=d
else:
    if f(b)*f(d)<0:
        a=d
ih=ih+1

while abs(a-b)>e:
    k=(f(b)-f(a))/abs(a-b)
    q=f(b)-k*b
    d=-q/k
    if f(a)*f(d)<0:
        b=d
    else:
        if f(b)*f(d)<0:
            a=d
    ih=ih+1

print (a)
print (b)
print (f(a))
print (f(b))
print (ih)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-0ff4a1e322b4> in <module>
#       6 ih=0
#       7 while abs(a-b)>e:
# ----> 8     k=(f(b)-f(a))/abs(a-b)
#       9     q=f(b)-k*b
#      10     d=-q/k
#
# <ipython-input-25-0ff4a1e322b4> in f(x)
#       1 def f(x):
# ----> 2     return x*x*x*x-x-1
#       3 a=-10
#       4 b=1
#       5 e=0.0001
#
# KeyboardInterrupt:

# %%
def f(x):
    return x*5-1
a=-3
b=4
k=(f(b)-f(a))/abs(a-b)
q=f(b)-k*b
print (k,' ',q)
# Out:
# 5.0   -1.0

# %%
def f(x):
    return x*x*x*x-x-1
a=-10
b=1
for i in range(10):
    k=(f(b)-f(a))/abs(a-b)
    q=f(b)-k*b
    if f(a)*f(d)<0:
        b=d
    else:
        if f(b)*f(d)<0:
            a=d
    print (a,' ',b)
# Out:
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
# -10   -0.7244919590004488
